# %%
# # Cell 1 — Install & login
# !pip uninstall -y diffusers -q
# !pip install --upgrade --pre diffusers accelerate peft safetensors transformers huggingface-hub datasets sentencepiece protobuf torchvision pillow tqdm

# %%
# from huggingface_hub import notebook_login
# notebook_login()  # click link, paste your HF token

# %%
# # Cell 2 — Download & patch SD3’s transformer folder
# from huggingface_hub import snapshot_download
# import json, os

# transformer_dir = snapshot_download(
#     repo_id="stabilityai/stable-diffusion-3-medium-diffusers",
#     subfolder="transformer",
#     use_auth_token=True
# )

# cfg_path = os.path.join(transformer_dir, "config.json")
# cfg = json.load(open(cfg_path))
# cfg.pop("num_attention_heads", None)   # remove broken field
# with open(cfg_path, "w") as f:
#     json.dump(cfg, f, indent=2)
# print("✅ Patched config.json in", transformer_dir)

# %%
# !ls

# %%
# !pip uninstall -y numpy
# !pip install numpy
# !pip install --upgrade --force-reinstall "numpy<2.3.0"

# %%
import numpy as np
print("NumPy version:", np.__version__)
# Out:
# NumPy version: 2.2.6

# %%
# Cell 3 — Load UNet and wrap in LoRA
import torch
from diffusers import UNet2DConditionModel
from peft import LoraConfig, get_peft_model

transformer_dir = "sd3_local/transformer"

# 1) Load full SD3 UNet into CPU, then move to GPU
unet = UNet2DConditionModel.from_pretrained(
    transformer_dir,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=False,
    device_map=None,
    local_files_only=True
)
unet = unet.to("cuda")

# 2) Configure and attach LoRA
lora_cfg = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["to_q","to_k","to_v"],  # only Q/K/V projections
    lora_dropout=0.05,
    bias="none"
)
unet_lora = get_peft_model(unet, lora_cfg)
print("✅ LoRA wrapped. LoRA params:", sum(p.numel() for p in unet_lora.parameters() if p.requires_grad))
# Out:
# Some weights of the model checkpoint at sd3_local/transformer were not used when initializing UNet2DConditionModel:
#  ['transformer_blocks.8.attn.add_v_proj.weight, time_text_embed.text_embedder.linear_2.bias, transformer_blocks.3.attn.to_out.0.bias, transformer_blocks.1.attn.add_k_proj.bias, transformer_blocks.23.attn.add_q_proj.weight, transformer_blocks.11.attn.to_k.weight, transformer_blocks.3.ff.net.0.proj.bias, transformer_blocks.17.attn.to_add_out.weight, transformer_blocks.19.attn.to_q.bias, transformer_blocks.23.attn.to_out.0.weight, transformer_blocks.19.norm1_context.linear.weight, transformer_blocks.21.attn.add_q_proj.weight, transformer_blocks.16.attn.to_k.weight, time_text_embed.text_embedder.linear_2.weight, transformer_blocks.18.attn.add_v_proj.bias, transformer_blocks.3.attn.add_v_proj.bias, transformer_blocks.11.attn.add_v_proj.bias, transformer_blocks.19.attn.add_v_proj.weight, transformer_blocks.0.attn.to_add_out.bias, transformer_blocks.18.norm1.linear.weight, transformer_blocks.9.attn.to_out.0.bias, transformer_blocks.23.norm1_context.linear.bias, transformer_blocks.6.attn.to_v.weight, transformer_blocks.3.ff.net.0.proj.weight, transformer_blocks.18.attn.to_add_out.bias, transformer_blocks.12.ff_context.net.0.proj.bias, transformer_blocks.3.norm1_context.linear.weight, transformer_blocks.15.norm1_context.linear.bias, transformer_blocks.14.norm1.linear.weight, transformer_blocks.1.attn.add_q_proj.weight, transformer_blocks.21.norm1.linear.bias, transformer_blocks.21.attn.add_v_proj.weight, transformer_blocks.1.ff_context.net.0.proj.bias, transformer_blocks.16.ff_context.net.0.proj.weight, transformer_blocks.17.attn.add_q_proj.bias, transformer_blocks.12.attn.to_v.bias, transformer_blocks.16.attn.add_v_proj.bias, transformer_blocks.5.attn.to_k.bias, transformer_blocks.3.attn.to_k.bias, transformer_blocks.22.ff.net.2.bias, transformer_blocks.5.norm1.linear.bias, transformer_blocks.8.ff_context.net.0.proj.weight, transformer_blocks.11.norm1.linear.weight, transformer_blocks.15.attn.to_q.bias, transformer_blocks.16.attn.add_q_proj.weight, pos_embed.proj.weight, transformer_blocks.10.norm1.linear.weight, transformer_blocks.22.attn.to_k.bias, transformer_blocks.15.ff_context.net.2.weight, transformer_blocks.5.attn.add_q_proj.bias, transformer_blocks.6.norm1.linear.bias, transformer_blocks.14.ff_context.net.2.bias, transformer_blocks.2.norm1_context.linear.weight, transformer_blocks.20.ff_context.net.0.proj.weight, transformer_blocks.11.attn.to_k.bias, transformer_blocks.13.attn.to_k.bias, transformer_blocks.1.norm1_context.linear.weight, transformer_blocks.5.ff.net.2.weight, transformer_blocks.0.norm1.linear.bias, transformer_blocks.12.ff.net.2.bias, transformer_blocks.2.ff_context.net.2.bias, transformer_blocks.20.ff.net.2.weight, transformer_blocks.3.ff_context.net.0.proj.bias, transformer_blocks.16.ff_context.net.2.bias, transformer_blocks.19.ff.net.2.bias, transformer_blocks.14.attn.add_q_proj.bias, transformer_blocks.20.norm1_context.linear.bias, transformer_blocks.7.norm1.linear.weight, context_embedder.bias, transformer_blocks.18.attn.to_v.weight, transformer_blocks.21.norm1.linear.weight, transformer_blocks.16.attn.to_add_out.bias, transformer_blocks.9.ff_context.net.2.weight, transformer_blocks.5.attn.to_k.weight, transformer_blocks.13.ff.net.2.bias, transformer_blocks.2.attn.add_k_proj.bias, transformer_blocks.15.norm1.linear.weight, transformer_blocks.4.attn.to_add_out.bias, transformer_blocks.14.attn.to_add_out.bias, transformer_blocks.4.attn.add_q_proj.weight, transformer_blocks.18.attn.add_k_proj.bias, transformer_blocks.1.attn.to_out.0.bias, transformer_blocks.13.attn.to_out.0.weight, transformer_blocks.10.ff_context.net.0.proj.bias, transformer_blocks.21.attn.to_out.0.weight, transformer_blocks.6.attn.to_v.bias, transformer_blocks.15.norm1.linear.bias, transformer_blocks.16.norm1.linear.weight, transformer_blocks.12.attn.to_out.0.bias, transformer_blocks.6.norm1_context.linear.bias, proj_out.bias, transformer_blocks.13.attn.add_v_proj.weight, transformer_blocks.4.norm1_context.linear.bias, transformer_blocks.4. ...
# Some weights of UNet2DConditionModel were not initialized from the model checkpoint at sd3_local/transformer and are newly initialized: ['mid_block.attentions.0.transformer_blocks.0.attn1.to_out.0.weight', 'up_blocks.1.attentions.2.transformer_blocks.0.ff.net.0.proj.bias', 'down_blocks.2.attentions.1.transformer_blocks.0.norm2.weight', 'mid_block.attentions.0.transformer_blocks.0.norm1.bias', 'up_blocks.3.attentions.1.transformer_blocks.0.attn1.to_out.0.weight', 'down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_v.weight', 'down_blocks.1.attentions.1.transformer_blocks.0.norm2.bias', 'up_blocks.0.resnets.2.norm2.bias', 'up_blocks.3.resnets.0.norm1.bias', 'up_blocks.3.resnets.2.conv_shortcut.bias', 'down_blocks.0.attentions.1.proj_in.bias', 'down_blocks.2.attentions.1.transformer_blocks.0.ff.net.2.weight', 'down_blocks.1.downsamplers.0.conv.weight', 'up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v.weight', 'up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0.bias', 'down_blocks.0.attentions.0.norm.bias', 'down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0.bias', 'up_blocks.2.attentions.1.transformer_blocks.0.norm2.bias', 'up_blocks.2.resnets.0.time_emb_proj.bias', 'mid_block.attentions.0.transformer_blocks.0.norm2.bias', 'up_blocks.1.resnets.0.conv1.bias', 'down_blocks.0.attentions.0.proj_in.bias', 'down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q.weight', 'down_blocks.1.resnets.0.conv1.bias', 'down_blocks.2.attentions.1.transformer_blocks.0.norm3.weight', 'down_blocks.1.attentions.0.proj_in.bias', 'down_blocks.2.attentions.1.norm.bias', 'up_blocks.2.attentions.1.transformer_blocks.0.norm1.weight', 'up_blocks.1.attentions.2.norm.weight', 'up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0.weight', 'mid_block.resnets.1.time_emb_proj.weight', 'up_blocks.1.resnets.2.norm2.bias', 'up_blocks.2.resnets.2.conv2.bias', 'down_blocks.0.attentions.0.transformer_blocks.0.ff.net.0.proj.weight', 'down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_k.weight', 'down_blocks.2.resnets.1.norm2.weight', 'up_blocks.2.attentions.2.transformer_blocks.0.attn1.to_q.weight', 'down_blocks.1.attentions.1.transformer_blocks.0.norm2.weight', 'up_blocks.3.attentions.0.transformer_blocks.0.attn2.to_k.weight', 'down_blocks.2.attentions.0.transformer_blocks.0.norm2.bias', 'down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0.weight', 'down_blocks.0.resnets.1.norm2.bias', 'up_blocks.2.attentions.0.proj_in.weight', 'down_blocks.0.attentions.0.transformer_blocks.0.norm1.bias', 'up_blocks.1.attentions.1.transformer_blocks.0.norm2.bias', 'up_blocks.2.attentions.1.proj_out.weight', 'up_blocks.0.resnets.2.conv1.weight', 'up_blocks.1.attentions.2.proj_out.bias', 'up_blocks.3.resnets.2.conv2.bias', 'up_blocks.3.attentions.2.transformer_blocks.0.norm1.bias', 'up_blocks.1.attentions.1.proj_out.bias', 'up_blocks.3.resnets.1.conv2.bias', 'down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_k.weight', 'down_blocks.0.resnets.1.time_emb_proj.weight', 'up_blocks.3.attentions.0.transformer_blocks.0.attn2.to_out.0.weight', 'down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_v.weight', 'up_blocks.3.resnets.2.norm2.weight', 'up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0.bias', 'up_blocks.1.attentions.0.norm.bias', 'up_blocks.1.attentions.1.proj_out.weight', 'time_embedding.linear_1.bias', 'down_blocks.3.resnets.1.time_emb_proj.weight', 'up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_v.weight', 'mid_block.attentions.0.transformer_blocks.0.norm3.weight', 'up_blocks.2.resnets.2.time_emb_proj.weight', 'down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0.bias', 'up_blocks.2.resnets.0.conv1.bias', 'up_blocks.2.attentions.2.proj_out.bias', 'up_blocks.1.resnets.0.conv1.weight', 'down_blocks.2.resnets.0.conv1.weight', 'up_blocks.2.attentions.2.transformer_blocks.0.ff.net.2.weight', 'up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_q.weight', 'up_blocks.2.resnets.1.conv_ ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ LoRA wrapped. LoRA params: 2652160

# %%
# Cell 4 — Fine-tune LoRA on your dataset
import torch, torch.nn.functional as F
from accelerate import Accelerator
from diffusers import StableDiffusion3Pipeline
from torch.utils.data import DataLoader
from transformers import CLIPTokenizer
from datasets import load_dataset
from torchvision import transforms
from PIL import Image
import os

# ───── CONFIG ─────
MODEL_ID    = "stabilityai/stable-diffusion-3-medium-diffusers"
TRAIN_JSON  = "lora_dataset.json"
OUTPUT_DIR  = "lora_sd3_panel"
BATCH_SIZE  = 4
EPOCHS      = 3
LR          = 1e-4
WARMUP      = 0.03
MAX_LEN     = 64
SEED        = 42
# ───────────────────

torch.manual_seed(SEED)
accelerator = Accelerator(mixed_precision="fp16")
device = accelerator.device

# 1) Load pipeline pieces (VAE, scheduler, text encoder)
pipe = StableDiffusion3Pipeline.from_pretrained(
    MODEL_ID, torch_dtype=torch.float16, use_auth_token=True
).to(device)
vae, scheduler, text_encoder = pipe.vae, pipe.scheduler, pipe.text_encoder

tokenizer = CLIPTokenizer.from_pretrained(
    MODEL_ID, subfolder="tokenizer", use_auth_token=True
)
img_tf = transforms.Compose([
    transforms.Resize((512,512), transforms.InterpolationMode.BILINEAR),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3),
])
# Out:
# Keyword arguments {'use_auth_token': True} are not expected by StableDiffusion3Pipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/9 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[7], line 31
#      26 device = accelerator.device
#      28 # 1) Load pipeline pieces (VAE, scheduler, text encoder)
#      29 pipe = StableDiffusion3Pipeline.from_pretrained(
#      30     MODEL_ID, torch_dtype=torch.float16, use_auth_token=True
# ---> 31 ).to(device)
#      32 vae, scheduler, text_encoder = pipe.vae, pipe.scheduler, pipe.text_encoder
#      34 tokenizer = CLIPTokenizer.from_pretrained(
#      35     MODEL_ID, subfolder="tokenizer", use_auth_token=True
#      36 )
#
# File /usr/local/lib/python3.11/dist-packages/diffusers/pipelines/pipeline_utils.py:541, in DiffusionPipeline.to(self, *args, **kwargs)
#     539     module.to(device=device)
#     540 elif not is_loaded_in_4bit_bnb and not is_loaded_in_8bit_bnb and not is_group_offloaded:
# --> 541     module.to(device, dtype)
#     543 if (
#     544     module.dtype == torch.float16
#     545     and str(device) in ["cpu"]
#     546     and not silence_dtype_warnings
#     547     and not is_offloaded
#     548 ):
#     549     logger.warning(
#     550         "Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It"
#     551         " is not recommended to move them to `cpu` as running them will fail. Please make"
#    (...)
#     554         " `torch_dtype=torch.float16` argument, or use another device for inference."
#     555     )
#
# File /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:4110, in PreTrainedModel.to(self, *args, **kwargs)
#    4105     if dtype_present_in_args:
#    4106         raise ValueError(
#    4107             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    4108             " `dtype` by passing the correct `torch_dtype` argument."
#    4109         )
# -> 4110 return super().to(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1174, in Module.to(self, *args, **kwargs)
#    1171         else:
#    1172             raise
# -> 1174 return self._apply(convert)
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 780 (4 times)]
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:780, in Module._apply(self, fn, recurse)
#     778 if recurse:
#     779     for module in self.children():
# --> 780         module._apply(fn)
#     782 def compute_should_use_set_data(tensor, tensor_applied):
#     783     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     784         # If the new tensor has compatible tensor type as the existing tensor,
#     785         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     790         # global flag to let the user control whether they want the future
#     791         # behavior of overwriting the existing tensor or not.
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:805, in Module._apply(self, fn, recurse)
#     801 # Tensors stored in modules are graph leaves, and we don't want to
#     802 # track autograd history of `param_applied`, so we have to use
#     803 # `with torch.no_grad():`
#     804 with torch.no_grad():
# --> 805     param_applied = fn(param)
#     806 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     808 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1160, in Module.to.<locals>.convert(t)
#    1153     if convert_to_format is not None and t.dim() in (4, 5):
#    1154         return t.to(
#    1155             device,
#    1156             dtype if t.is_floating_point() or t.is_complex() else None,
#    1157             non_blocking,
#    1158             memory_format=convert_to_format,
#    1159         )
# -> 1160     return t.to(
#    1161         device,
#    1162         dtype if t.is_floating_point() or t.is_complex() else None,
#    1163         non_blocking,
#    1164     )
#    1165 except NotImplementedError as e:
#    1166     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 32.00 MiB. GPU 0 has a total capacity of 23.64 GiB of which 29.25 MiB is free. Process 4153344 has 446.00 MiB memory in use. Process 4166664 has 23.17 GiB memory in use. Of the allocated memory 22.46 GiB is allocated by PyTorch, and 274.86 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
# 2) Dataset → DataLoader
ds = load_dataset("json", data_files=TRAIN_JSON)["train"]
def preprocess(ex):
    img = Image.open(ex["image"]).convert("RGB")
    ex["pixel_values"] = img_tf(img)
    ex["input_ids"] = tokenizer(
        ex["caption"],
        padding="max_length", truncation=True, max_length=MAX_LEN,
        return_tensors="pt"
    ).input_ids[0]
    return ex

ds = ds.map(preprocess, remove_columns=["image","caption"])
ds.set_format(type="torch", columns=["pixel_values","input_ids"])
loader = DataLoader(
    ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, pin_memory=True,
    collate_fn=lambda b: {
        "pixel_values": torch.stack([x["pixel_values"] for x in b]),
        "input_ids":    torch.stack([x["input_ids"]    for x in b])
    }
)

# %%
# 3) Optimizer & LR scheduler on LoRA params
optimizer = torch.optim.AdamW(unet_lora.parameters(), lr=LR)
total_steps = len(loader) * EPOCHS
lr_scheduler = torch.optim.lr_scheduler.LinearLR(
    optimizer, start_factor=WARMUP, total_iters=total_steps
)

# 4) Prepare for fp16/multi-GPU
unet_lora, optimizer, loader, lr_scheduler = accelerator.prepare(
    unet_lora, optimizer, loader, lr_scheduler
)

# %%
# 5) Training loop
for epoch in range(1, EPOCHS+1):
    unet_lora.train()
    running_loss = 0.0
    for batch in loader:
        # encode to latents
        with torch.no_grad():
            latents = vae.encode(batch["pixel_values"].to(device)).latent_dist.sample()
            latents *= vae.config.scaling_factor

        # add noise
        noise = torch.randn_like(latents)
        timesteps = torch.randint(
            0, scheduler.config.num_train_timesteps,
            (latents.shape[0],), device=device
        ).long()
        noisy = scheduler.add_noise(latents, noise, timesteps)

        # text → embeddings
        emb = text_encoder(batch["input_ids"].to(device))[0]

        # UNet forward
        noise_pred = unet_lora(noisy, timesteps, encoder_hidden_states=emb).sample
        loss = F.mse_loss(noise_pred, noise)

        accelerator.backward(loss)
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        running_loss += loss.item()

    print(f"Epoch {epoch}/{EPOCHS} — avg loss {running_loss/len(loader):.4f}")

# %%
# 6) Save adapters
os.makedirs(OUTPUT_DIR, exist_ok=True)
unet_lora.save_pretrained(OUTPUT_DIR)
print("✅ LoRA adapters saved to", OUTPUT_DIR)
